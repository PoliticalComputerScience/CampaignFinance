# %% [markdown]
# # Analysis - Congressional Fundraising and Votes

# %% [markdown]
# ### Set-up

# %%
#import dependencies
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set()
# %matplotlib inline
#import dataset
data = pd.read_csv('new data.csv')
data['vote'] = [0 for _ in range(len(data))]
data['party'] = [0 for _ in range(len(data))]
#remove candidates for which we have no fundrasing data
data = data[data['amount'] != '0']

#prepare for cleaning
a = np.array(data.as_matrix())
data[1:10]
# Out:
#                                       text            amount  vote  party
# 1                                Candidate  Candidate Raised     0      0
# 2   Bradley Byrne (R) • Incumbent • Winner           1366370     0      0
# 3                      Alabama District 02               NaN     0      0
# 4                                Candidate  Candidate Raised     0      0
# 5     Martha Roby (R) • Incumbent • Winner           1381821     0      0
# 8                      Alabama District 03               NaN     0      0
# 9                                Candidate  Candidate Raised     0      0
# 10  Mike D Rogers (R) • Incumbent • Winner           1137285     0      0
# 11                         Jesse Smith (D)              9810     0      0

# %% [markdown]
# ### Cleaning

# %% [markdown]
# #### Clean Fundraising Data

# %%
#trim candidate names
for i in range(len(a)):
    t = a[i][0].split(' (')
    a[i][0] = t[0]
    if len(t) > 1:
        a[i][3] = t[1].split(')')[0]

#split large dataset into small arrays by district
b = np.split(a, (a.transpose()[0] == 'Candidate').nonzero()[0] - 1)
for i in range(len(b)):
    b[i] = b[i][1:]
    #todo: add votes header

# %% [markdown]
# #### Clean Voting Data

# %%
#read votes data
voting = pd.read_csv('voting2.csv')
v = voting.values
to_del = []
for i in  range(len(v)):
    v[i][0] = v[i][0].split(' (')
    if '%' in v[i][0][1]:
        t = v[i][0][1].split(') ')[1]
        vote = t[:t.index('%')]
        try:
            vote = float(vote)
            if vote < 5:
                to_del.append(i)
            v[i][0][1] = vote
        except ValueError:
            #delete rows for which we don't have vote data
            to_del.append(i)
    else:
        to_del.append(i)
v = np.delete(v, to_del, 0)
for i in range(len(a)):
    if a[i][3] == 0:
        j = 1
    elif a[i][3] == 'R':
        a[i][3] = 0.0
    elif a[i][3] == 'D':
        a[i][3] = 1.0
    else:
        a[i][3] = 0.5

# %% [markdown]
# #### Match Vote % to Candidates

# %%
#todo: make more efficient
for k in range(len(v)):
    for i in range(len(b)):
        if v[k][0][0] in b[i][:,0]:
            for j in range(len(b[i])):
                if v[k][0][0] in b[i][j]:
                    b[i][j][2] = v[k][0][1]

# %% [markdown]
# #### Example Chunk

# %%
df = pd.DataFrame(b[63])
df
#todo: convert headers
# Out:
#               0                 1     2  3
# 0     Candidate  Candidate Raised     0  0
# 1   Ken Calvert           1443899  58.8  0
# 2  Tim Sheridan            138396  41.2  1

# %% [markdown]
# ### Calculations

# %% [markdown]
# #### Calculate % Raised for Each Candiate in Chunk

# %%
def calc(x):
    total = sum(x[1:][:,1].astype(int))
    spends = [i / total for i in x[1:][:,1].astype(int)]
    votes = x[1:][:,2].astype(float)
    #return list of lists: [% raised, % votes]
    i = [list(a) for a in zip(spends, votes, x[1:][:,3])]
    for j in i:
        j.append(total)
    return i

d = np.array([[0,0, 0, 0]])
for i in range(1, len(b)):
    d = np.concatenate((d, calc(b[i])), axis = 0)
x, y, = d[:,0], d[:,1]
plt.scatter(x, y)

# %% [markdown]
# #### Clean Data

# %%
#remove rows without voting data
d = d[d[:,1] != 0]

#remove rows with highly imbalanced funding
d = d[d[:,0] < .999]
d = d[d[:,0] > .001]
x, y, p, z = d[:,0], d[:,1], d[:,2], d[:,3]

# %% [markdown]
# ### Graphing

# %% [markdown]
# #### Basic Trend

# %%
plt.figure(figsize=(10, 7.5))

#plot linear regression
plt.ylim(0, 100)
plt.xlim(0, 1)
sns.regplot(x, y, scatter = True, robust = False, n_boot = 100)

#add text
plt.title('Vote % by Fundraising %', fontsize=16)
plt.annotate('2016 Election data from https://www.opensecrets.org/races/', (0,0), (-80,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()

# %% [markdown]
# #### Points shaded by amount raised

# %%
plt.figure(figsize=(10, 7.5))

#plot linear regression
plt.ylim(0, 100)
plt.xlim(0, 1)
sns.regplot(x, y, scatter = False, robust = False, n_boot = 100)

#color points by amount raised (darker = more)
#scale z to 1
z1 = z / max(z)
z2 = z1 ** .5
cmap = sns.cubehelix_palette(start = 2.4, rot = .2, as_cmap=True)
plt.scatter(x, y, c=z2, s=50, cmap=cmap)

#add text
plt.title('Vote % by Fundraising %', fontsize=16)
plt.annotate('2016 Election data from https://www.opensecrets.org/races/', (0,0), (-80,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()

# %% [markdown]
# #### Points colored by party

# %%
plt.figure(figsize=(10, 7.5))
#plt.annotate(fit[0][1], (0,0), (-80,-20), fontsize=8)
#plot linear regression
plt.ylim(0, 100)
plt.xlim(0, 1)

#color points by amount raised (darker = more)
#scale z to 1
z1 = z / max(z)
z2 = z1 ** .33

plt.scatter(x[p == 1.0], y[p == 1.0], c=z2[p == 1.0], s=50, cmap='Blues')
plt.scatter(x[p == 0.0], y[p == 0.0], c=z2[p == 0.0], s=50, cmap='Reds')
plt.scatter(x[p == 0.5], y[p == 0.5], c=z2[p == 0.5], s=50, cmap='Greens')

#add text
plt.title('Vote % by Fundraising %', fontsize=16)
plt.annotate('2016 Election data from https://www.opensecrets.org/races/', (0,0), (-80,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()

# %% [markdown]
# As you can see, the data is pretty consistent between D and R (the lines overlap so much you can't differentiate), however, there is not enough data for third-party candidates

# %%
sns.regplot(x[p == 1.0], y[p == 1.0], scatter = False, robust = False, n_boot = 100, ci = None, color='b')
sns.regplot(x[p == 0.0], y[p == 0.0], scatter = False, robust = False, n_boot = 100, ci = None, color='r')
#sns.regplot(x[p == 0.5], y[p == 0.5], scatter = False, robust = False, n_boot = 100, ci = None, color='g')
plt.ylim(0, 100)
plt.xlim(0, 1)
plt.scatter(x[p == 1.0], y[p == 1.0], c=z2[p == 1.0], s=50, cmap='Blues')
plt.scatter(x[p == 0.0], y[p == 0.0], c=z2[p == 0.0], s=50, cmap='Reds')
plt.scatter(x[p == 0.5], y[p == 0.5], c=z2[p == 0.5], s=50, cmap='Greens')
mD = np.polyfit(x[p == 1.0], y[p == 1.0], 1)
mR = np.polyfit(x[p == 0.0], y[p == 0.0], 1)
print('% difference between D and R regression: ')
print((abs(mD - mR) / (sum(mD, mR) / 2)) * 100)
# Out:
# % difference between D and R regression:
# [ 0.07601229  0.29589294]

# %% [markdown]
# ### Misc Analysis

# %%
s = x[y > 50]
print(s.mean())
print(x.mean())
# Out:
# 0.862942109515
# 0.505074873992

# %%
from scipy.stats import kendalltau
sns.jointplot(x, y, kind="kde", stat_func=kendalltau, color="#4CB391")

# %%
x1, y1, z1 = x[y > 20], y[y > 20], z[y > 20]
x1, y1, z1 = x1[y1 < 80], y1[y1 < 80], z1[y1 < 80]

plt.figure(figsize=(10, 7.5))
#plt.annotate(fit[0][1], (0,0), (-80,-20), fontsize=8)
#plot linear regression
plt.ylim(0, 100)
plt.xlim(0, 1)
sns.regplot(x1, y1, scatter = False, robust = False, n_boot = 100)

#color points by amount raised (darker = more)
#scale z to 1
z1 = z1 / max(z1)
z2 = z1 ** .33
cmap = sns.cubehelix_palette(start = 2.4, rot = .2, as_cmap=True)
plt.scatter(x1, y1, c=z2, s=50, cmap=cmap)

#add text
plt.title('Vote % by Fundraising %', fontsize=16)
plt.annotate('2016 Election data from https://www.opensecrets.org/races/', (0,0), (-80,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')
plt.show()
